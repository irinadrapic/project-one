# %%
# %matplotlib notebook
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
health_nom = pd.read_csv("Health Behaviours Nominal.csv")
mort_2015 = os.path.join("datas", "new_mortality", "2015 mortality.csv")
mortality_nom = pd.read_csv(mort_2015)
mortality_nom = mortality_nom.rename(columns={"Geography":"City","2015":"Mortality Count"})
mortality_nom
# Out:
#                                      City Age group  Mortality Count
# 0    Abbotsford-Mission, British Columbia  All ages             1252
# 1                         Barrie, Ontario  All ages             1426
# 2                      Brantford, Ontario  All ages             1339
# 3                        Calgary, Alberta  All ages             6655
# 4                       Edmonton, Alberta  All ages             8173
# 5                Greater Sudbury, Ontario  All ages             1698
# 6                         Guelph, Ontario  All ages             1077
# 7                    Halifax, Nova Scotia  All ages             3136
# 8                       Hamilton, Ontario  All ages             6725
# 9               Kelowna, British Columbia  All ages             1717
# 10                      Kingston, Ontario  All ages             1495
# 11  Kitchener-Cambridge-Waterloo, Ontario  All ages             3558
# 12                        London, Ontario  All ages             4225
# ...

# %%
mortality_health = pd.merge(mortality_nom,health_nom, on='City').drop(columns=["Age"])
mortality_health =
# Out:
#                                      City Age group  Mortality Count  Asthma  \
# 0    Abbotsford-Mission, British Columbia  All ages             1252   15500
# 1                         Barrie, Ontario  All ages             1426   14700
# 2                      Brantford, Ontario  All ages             1339   11800
# 3                        Calgary, Alberta  All ages             6655  108000
# 4                       Edmonton, Alberta  All ages             8173  114500
# 5                Greater Sudbury, Ontario  All ages             1698   12300
# 6                         Guelph, Ontario  All ages             1077    9300
# 7                    Halifax, Nova Scotia  All ages             3136   35700
# 8                       Hamilton, Ontario  All ages             6725   50100
# 9               Kelowna, British Columbia  All ages             1717   12100
# 10                      Kingston, Ontario  All ages             1495   15300
# ...
