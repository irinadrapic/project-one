# %%
# %matplotlib notebook
import os
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
health_table = pd.read_csv("Health_Indicators_new.csv")
population_table = pd.read_csv("2015_population.csv")

df = population_table.merge(health_table,how='outer',on='City')
population_table.rename(columns={'Geography':'City'})
# Out:
#     Unnamed: 0                                   City Age group  population  \
# 0            0   Abbotsford-Mission, British Columbia  All ages      184021
# 1            1                        Barrie, Ontario  All ages      202264
# 2            2                     Brantford, Ontario  All ages      144109
# 3            3                       Calgary, Alberta  All ages     1432169
# 4            4                      Edmonton, Alberta  All ages     1358345
# 5            5               Greater Sudbury, Ontario  All ages      165261
# 6            6                        Guelph, Ontario  All ages      153290
# 7            7                   Halifax, Nova Scotia  All ages      416824
# 8            8                      Hamilton, Ontario  All ages      769853
# 9            9              Kelowna, British Columbia  All ages      195305
# 10          10                      Kingston, Ontario  All ages      169643
# ...
