# %%
import os
import pandas as pd

# %% [markdown]
# #### population data from: https://www150.statcan.gc.ca/t1/tbl1/en/cv.action?pid=1710007801

# %%
mort_file_2015 = os.path.join("datas", "new_mortality", "2015 mortality.csv")

mort_2015 = pd.read_csv(mort_file_2015)
mort_2015 = mort_2015.rename(columns={"2015": "Number of Mortality"})

# %%
# population file
pop_file = os.path.join("datas", "population", "population.csv")
pop_df = pd.read_csv(pop_file)

# select only 2015, then clean
pop_df = pop_df[["Geography", "Age group", "2015"]]
pop_df = pop_df.rename(columns={"2015":"population"})
pop_df = pop_df.sort_values(by=["Geography"])
pop_df = pop_df.reset_index(drop=True)

# Change string type to int type
pop_df["population"] = pop_df["population"].str.replace(",", "")
pop_df["population"] = pop_df["population"].astype(int)
pop_df.dtypes
# Out:
# Geography     object
# Age group     object
# population     int32
# dtype: object

# %%
# Merge dataframe
merged = pd.merge(pop_df,mort_2015)

# Calculate mortality rate
rate = (100*(merged["Number of Mortality"]/merged["population"])).map("{:,.2f}%".format)
merged["Mortality Rate"] = rate
merged
# Out:
#                                 Geography Age group  population  \
# 0    Abbotsford-Mission, British Columbia  All ages      184021
# 1                         Barrie, Ontario  All ages      202264
# 2                      Brantford, Ontario  All ages      144109
# 3                        Calgary, Alberta  All ages     1432169
# 4                       Edmonton, Alberta  All ages     1358345
# 5                Greater Sudbury, Ontario  All ages      165261
# 6                         Guelph, Ontario  All ages      153290
# 7                    Halifax, Nova Scotia  All ages      416824
# 8                       Hamilton, Ontario  All ages      769853
# 9               Kelowna, British Columbia  All ages      195305
# 10                      Kingston, Ontario  All ages      169643
# 11  Kitchener-Cambridge-Waterloo, Ontario  All ages      510527
# 12                        London, Ontario  All ages      505837
# 13                 Moncton, New Brunswick  All ages      147489
# 14                       Montreal, Quebec  All ages     4045877
# 15                        Oshawa, Ontario  All ages      388474
# 16        Ottawa-Gatineau, Ontario/Quebec  All ages     1329433
# 17                  Peterborough, Ontario  All ages      123344
# 18                         Quebec, Quebec  All ages      801050
# 19                   Regina, Saskatchewan  All ages      240583
# 20                       Saguenay, Quebec  All ages      159987
# 21              Saint John, New Brunswick  All ages      127218
# 22                Saskatoon, Saskatchewan  All ages      305010
# 23                     Sherbrooke, Quebec  All ages      213219
# 24        St. Catharines-Niagara, Ontario  All ages      408488
# 25  St. John's, Newfoundland and Labrador  All ages      214523
# 26                   Thunder Bay, Ontario  All ages      124625
# 27                       Toronto, Ontario  All ages     6116725
# 28                 Trois-Rivieres, Quebec  All ages      156767
# 29            Vancouver, British Columbia  All ages     2509942
# 30             Victoria, British Columbia  All ages      366852
# 31                       Windsor, Ontario  All ages      336391
# 32                     Winnipeg, Manitoba  All ages      794067
#
#     Number of Mortality Mortality Rate
# 0                  1252          0.68%
# 1                  1426          0.71%
# 2                  1339          0.93%
# 3                  6655          0.46%
# 4                  8173          0.60%
# 5                  1698          1.03%
# 6                  1077          0.70%
# 7                  3136          0.75%
# 8                  6725          0.87%
# 9                  1717          0.88%
# 10                 1495          0.88%
# 11                 3558          0.70%
# 12                 4225          0.84%
# 13                 1096          0.74%
# 14                27843          0.69%
# 15                 2635          0.68%
# 16                 8277          0.62%
# 17                 1337          1.08%
# 18                 5829          0.73%
# 19                 1780          0.74%
# 20                 1372          0.86%
# 21                 1161          0.91%
# 22                 2028          0.66%
# 23                 1555          0.73%
# 24                 4350          1.06%
# 25                 1586          0.74%
# 26                 1343          1.08%
# 27                33756          0.55%
# 28                 1556          0.99%
# 29                15290          0.61%
# 30                 3300          0.90%
# 31                 2750          0.82%
# 32                 6231          0.78%

# %%
rate = (100*(merged["Number of Mortality"]/merged["population"])).map("{:,.2f}%".format)
merged["Mortality Rate"] = rate
merged
# Out:
#                                 Geography Age group  population  \
# 0    Abbotsford-Mission, British Columbia  All ages      184021
# 1                         Barrie, Ontario  All ages      202264
# 2                      Brantford, Ontario  All ages      144109
# 3                        Calgary, Alberta  All ages     1432169
# 4                       Edmonton, Alberta  All ages     1358345
# 5                Greater Sudbury, Ontario  All ages      165261
# 6                         Guelph, Ontario  All ages      153290
# 7                    Halifax, Nova Scotia  All ages      416824
# 8                       Hamilton, Ontario  All ages      769853
# 9               Kelowna, British Columbia  All ages      195305
# 10                      Kingston, Ontario  All ages      169643
# 11  Kitchener-Cambridge-Waterloo, Ontario  All ages      510527
# 12                        London, Ontario  All ages      505837
# 13                 Moncton, New Brunswick  All ages      147489
# 14                       Montreal, Quebec  All ages     4045877
# 15                        Oshawa, Ontario  All ages      388474
# 16        Ottawa-Gatineau, Ontario/Quebec  All ages     1329433
# 17                  Peterborough, Ontario  All ages      123344
# 18                         Quebec, Quebec  All ages      801050
# 19                   Regina, Saskatchewan  All ages      240583
# 20                       Saguenay, Quebec  All ages      159987
# 21              Saint John, New Brunswick  All ages      127218
# 22                Saskatoon, Saskatchewan  All ages      305010
# 23                     Sherbrooke, Quebec  All ages      213219
# 24        St. Catharines-Niagara, Ontario  All ages      408488
# 25  St. John's, Newfoundland and Labrador  All ages      214523
# 26                   Thunder Bay, Ontario  All ages      124625
# 27                       Toronto, Ontario  All ages     6116725
# 28                 Trois-Rivieres, Quebec  All ages      156767
# 29            Vancouver, British Columbia  All ages     2509942
# 30             Victoria, British Columbia  All ages      366852
# 31                       Windsor, Ontario  All ages      336391
# 32                     Winnipeg, Manitoba  All ages      794067
#
#     Number of Mortality Mortality Rate
# 0                  1252          0.68%
# 1                  1426          0.71%
# 2                  1339          0.93%
# 3                  6655          0.46%
# 4                  8173          0.60%
# 5                  1698          1.03%
# 6                  1077          0.70%
# 7                  3136          0.75%
# 8                  6725          0.87%
# 9                  1717          0.88%
# 10                 1495          0.88%
# 11                 3558          0.70%
# 12                 4225          0.84%
# 13                 1096          0.74%
# 14                27843          0.69%
# 15                 2635          0.68%
# 16                 8277          0.62%
# 17                 1337          1.08%
# 18                 5829          0.73%
# 19                 1780          0.74%
# 20                 1372          0.86%
# 21                 1161          0.91%
# 22                 2028          0.66%
# 23                 1555          0.73%
# 24                 4350          1.06%
# 25                 1586          0.74%
# 26                 1343          1.08%
# 27                33756          0.55%
# 28                 1556          0.99%
# 29                15290          0.61%
# 30                 3300          0.90%
# 31                 2750          0.82%
# 32                 6231          0.78%

# %% [markdown]
# #### Median income: https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1110000801&pickMembers%5B0%5D=1.42

# %%
med_inc_file = os.path.join("datas", "income", "median_income.csv")
income_df = pd.read_csv(med_inc_file)
income_df = income_df.dropna()

# drop other years except 2015
income_df = income_df.drop(columns=["2013", "2014", "2016"])

# change type to integer
income_df["2015"] = income_df["2015"].str.replace(",","").astype(int)

# calculate mean of ottawa-gatinuea Quebec part and Ont part
# Ottawa-Gatineau, Ontario/Quebec
x = (income_df["2015"][9] + income_df["2015"][10])/2

# append row to df
income_df = income_df.append({"Geography":
                              "Ottawa-Gatineau, Ontario/Quebec","2015":x}, 
                             ignore_index=True)

# now get rid of Quebec part and Ont part.
income_df = income_df.drop(income_df.index[9:11])

# sort it alphabatically
income_df = income_df.sort_values(by=["Geography"]).reset_index(drop=True)

# rename year to median income
income_df = income_df.rename(columns={"2015":"Median Income"})
income_df
# Out:
#                                 Geography  Median Income
# 0    Abbotsford-Mission, British Columbia        30290.0
# 1                         Barrie, Ontario        35270.0
# 2                      Brantford, Ontario        33010.0
# 3                        Calgary, Alberta        43130.0
# 4                       Edmonton, Alberta        43190.0
# 5                Greater Sudbury, Ontario        38560.0
# 6                         Guelph, Ontario        39260.0
# 7                    Halifax, Nova Scotia        36390.0
# 8                       Hamilton, Ontario        35990.0
# 9               Kelowna, British Columbia        34610.0
# 10                      Kingston, Ontario        37280.0
# 11  Kitchener-Cambridge-Waterloo, Ontario        36110.0
# 12                        London, Ontario        34670.0
# 13                 Moncton, New Brunswick        33310.0
# 14                       Montreal, Quebec        32270.0
# 15                        Oshawa, Ontario        38630.0
# 16        Ottawa-Gatineau, Ontario/Quebec        41160.0
# 17                  Peterborough, Ontario        33130.0
# 18                         Québec, Quebec        37780.0
# 19                   Regina, Saskatchewan        42930.0
# 20                       Saguenay, Quebec        32790.0
# 21              Saint John, New Brunswick        32830.0
# 22                Saskatoon, Saskatchewan        40500.0
# 23                     Sherbrooke, Quebec        31200.0
# 24        St. Catharines-Niagara, Ontario        31730.0
# 25  St. John's, Newfoundland and Labrador        38570.0
# 26                   Thunder Bay, Ontario        36940.0
# 27                       Toronto, Ontario        31650.0
# 28                 Trois-Rivieres, Quebec        30270.0
# 29            Vancouver, British Columbia        32140.0
# 30             Victoria, British Columbia        38210.0
# 31                       Windsor, Ontario        33380.0
# 32                     Winnipeg, Manitoba        35030.0

# %%
merge = pd.merge(merged,income_df)
merge
# Out:
#                                 Geography Age group  population  \
# 0    Abbotsford-Mission, British Columbia  All ages      184021
# 1                         Barrie, Ontario  All ages      202264
# 2                      Brantford, Ontario  All ages      144109
# 3                        Calgary, Alberta  All ages     1432169
# 4                       Edmonton, Alberta  All ages     1358345
# 5                Greater Sudbury, Ontario  All ages      165261
# 6                         Guelph, Ontario  All ages      153290
# 7                    Halifax, Nova Scotia  All ages      416824
# 8                       Hamilton, Ontario  All ages      769853
# 9               Kelowna, British Columbia  All ages      195305
# 10                      Kingston, Ontario  All ages      169643
# 11  Kitchener-Cambridge-Waterloo, Ontario  All ages      510527
# 12                        London, Ontario  All ages      505837
# 13                 Moncton, New Brunswick  All ages      147489
# 14                       Montreal, Quebec  All ages     4045877
# 15                        Oshawa, Ontario  All ages      388474
# 16        Ottawa-Gatineau, Ontario/Quebec  All ages     1329433
# 17                  Peterborough, Ontario  All ages      123344
# 18                   Regina, Saskatchewan  All ages      240583
# 19                       Saguenay, Quebec  All ages      159987
# 20              Saint John, New Brunswick  All ages      127218
# 21                Saskatoon, Saskatchewan  All ages      305010
# 22                     Sherbrooke, Quebec  All ages      213219
# 23        St. Catharines-Niagara, Ontario  All ages      408488
# 24  St. John's, Newfoundland and Labrador  All ages      214523
# 25                   Thunder Bay, Ontario  All ages      124625
# 26                       Toronto, Ontario  All ages     6116725
# 27                 Trois-Rivieres, Quebec  All ages      156767
# 28            Vancouver, British Columbia  All ages     2509942
# 29             Victoria, British Columbia  All ages      366852
# 30                       Windsor, Ontario  All ages      336391
# 31                     Winnipeg, Manitoba  All ages      794067
#
#     Number of Mortality Mortality Rate  Median Income
# 0                  1252          0.68%        30290.0
# 1                  1426          0.71%        35270.0
# 2                  1339          0.93%        33010.0
# 3                  6655          0.46%        43130.0
# 4                  8173          0.60%        43190.0
# 5                  1698          1.03%        38560.0
# 6                  1077          0.70%        39260.0
# 7                  3136          0.75%        36390.0
# 8                  6725          0.87%        35990.0
# 9                  1717          0.88%        34610.0
# 10                 1495          0.88%        37280.0
# 11                 3558          0.70%        36110.0
# 12                 4225          0.84%        34670.0
# 13                 1096          0.74%        33310.0
# 14                27843          0.69%        32270.0
# 15                 2635          0.68%        38630.0
# 16                 8277          0.62%        41160.0
# 17                 1337          1.08%        33130.0
# 18                 1780          0.74%        42930.0
# 19                 1372          0.86%        32790.0
# 20                 1161          0.91%        32830.0
# 21                 2028          0.66%        40500.0
# 22                 1555          0.73%        31200.0
# 23                 4350          1.06%        31730.0
# 24                 1586          0.74%        38570.0
# 25                 1343          1.08%        36940.0
# 26                33756          0.55%        31650.0
# 27                 1556          0.99%        30270.0
# 28                15290          0.61%        32140.0
# 29                 3300          0.90%        38210.0
# 30                 2750          0.82%        33380.0
# 31                 6231          0.78%        35030.0

# %% [markdown]
# ### Merge Health indicators

# %%
health_file = os.path.join("datas", "Health", "Health_Indicators.csv")

health_df = pd.read_csv(health_file)
health_df = health_df.dropna()

merged_df = pd.merge(merge, health_df)

# Get rid of age group
merged_df = merged_df.drop(columns=["Age group"])
merged_df
# Out:
#                                 Geography  population  Number of Mortality  \
# 0    Abbotsford-Mission, British Columbia      184021                 1252
# 1                         Barrie, Ontario      202264                 1426
# 2                      Brantford, Ontario      144109                 1339
# 3                        Calgary, Alberta     1432169                 6655
# 4                       Edmonton, Alberta     1358345                 8173
# 5                Greater Sudbury, Ontario      165261                 1698
# 6                         Guelph, Ontario      153290                 1077
# 7                    Halifax, Nova Scotia      416824                 3136
# 8                       Hamilton, Ontario      769853                 6725
# 9               Kelowna, British Columbia      195305                 1717
# 10                      Kingston, Ontario      169643                 1495
# 11  Kitchener-Cambridge-Waterloo, Ontario      510527                 3558
# 12                        London, Ontario      505837                 4225
# 13                 Moncton, New Brunswick      147489                 1096
# 14                       Montreal, Quebec     4045877                27843
# 15                        Oshawa, Ontario      388474                 2635
# 16        Ottawa-Gatineau, Ontario/Quebec     1329433                 8277
# 17                  Peterborough, Ontario      123344                 1337
# 18                   Regina, Saskatchewan      240583                 1780
# 19                       Saguenay, Quebec      159987                 1372
# 20              Saint John, New Brunswick      127218                 1161
# 21                Saskatoon, Saskatchewan      305010                 2028
# 22                     Sherbrooke, Quebec      213219                 1555
# 23        St. Catharines-Niagara, Ontario      408488                 4350
# 24  St. John's, Newfoundland and Labrador      214523                 1586
# 25                   Thunder Bay, Ontario      124625                 1343
# 26                       Toronto, Ontario     6116725                33756
# 27                 Trois-Rivieres, Quebec      156767                 1556
# 28            Vancouver, British Columbia     2509942                15290
# 29             Victoria, British Columbia      366852                 3300
# 30                       Windsor, Ontario      336391                 2750
# 31                     Winnipeg, Manitoba      794067                 6231
#
#    Mortality Rate  Median Income  \
# 0           0.68%        30290.0
# 1           0.71%        35270.0
# 2           0.93%        33010.0
# 3           0.46%        43130.0
# 4           0.60%        43190.0
# 5           1.03%        38560.0
# 6           0.70%        39260.0
# 7           0.75%        36390.0
# 8           0.87%        35990.0
# 9           0.88%        34610.0
# 10          0.88%        37280.0
# 11          0.70%        36110.0
# 12          0.84%        34670.0
# 13          0.74%        33310.0
# 14          0.69%        32270.0
# 15          0.68%        38630.0
# 16          0.62%        41160.0
# 17          1.08%        33130.0
# 18          0.74%        42930.0
# 19          0.86%        32790.0
# 20          0.91%        32830.0
# 21          0.66%        40500.0
# 22          0.73%        31200.0
# 23          1.06%        31730.0
# 24          0.74%        38570.0
# 25          1.08%        36940.0
# 26          0.55%        31650.0
# 27          0.99%        30270.0
# 28          0.61%        32140.0
# 29          0.90%        38210.0
# 30          0.82%        33380.0
# 31          0.78%        35030.0
#
#    Body mass index, adjusted self-reported, adult (18 years and over), obese  \
# 0                                              23.75%
# 1                                              21.46%
# 2                                              17.97%
# 3                                              18.31%
# 4                                              19.51%
# 5                                              23.84%
# 6                                              19.57%
# 7                                              22.84%
# 8                                              19.21%
# 9                                              16.18%
# 10                                             24.88%
# 11                                             20.78%
# 12                                             18.27%
# 13                                             30.78%
# 14                                             17.55%
# 15                                             24.82%
# 16                                             18.44%
# 17                                             24.00%
# 18                                             19.74%
# 19                                             17.69%
# 20                                             24.37%
# 21                                             18.20%
# 22                                             18.20%
# 23                                             22.79%
# 24                                             26.80%
# 25                                             23.27%
# 26                                             15.73%
# 27                                             19.33%
# 28                                             13.03%
# 29                                             16.00%
# 30                                             26.22%
# 31                                             19.94%
#
#    Body mass index, adjusted self-reported, adult (18 years and over), overweight  \
# 0                                              23.75%
# 1                                              21.70%
# 2                                              24.56%
# 3                                              28.86%
# 4                                              29.00%
# 5                                              25.35%
# 6                                              26.55%
# 7                                              27.16%
# 8                                              28.20%
# 9                                              27.65%
# 10                                             23.99%
# 11                                             25.74%
# 12                                             24.06%
# 13                                             27.60%
# 14                                             26.87%
# 15                                             29.50%
# 16                                             27.81%
# 17                                             24.57%
# 18                                             29.68%
# 19                                             30.56%
# 20                                             27.28%
# 21                                             30.03%
# 22                                             32.27%
# 23                                             26.76%
# 24                                             26.01%
# 25                                             27.84%
# 26                                             25.91%
# 27                                             25.90%
# 28                                             26.60%
# 29                                             29.63%
# 30                                             23.51%
# 31                                             25.40%
#
#    Current smoker, daily Diabetes Heavy drinking High blood pressure  \
# 0                  8.37%    5.65%         13.42%              10.76%
# 1                  9.79%    6.87%         16.22%              15.28%
# 2                 13.12%    5.90%         17.07%              15.06%
# 3                  7.76%    3.57%         15.24%              11.19%
# 4                 11.10%    4.64%         15.76%              12.67%
# 5                 15.37%    7.87%         17.73%              19.85%
# 6                  9.07%    4.44%         12.39%              14.48%
# 7                 10.58%    6.79%         20.56%              13.48%
# 8                 10.56%    5.95%         16.82%              16.50%
# 9                  8.40%    4.56%         17.00%              13.88%
# 10                10.85%    6.01%         18.16%              15.39%
# 11                11.99%    5.48%         17.81%              14.89%
# 12                11.11%    5.77%         17.38%              14.83%
# 13                 9.09%    6.85%         17.02%              17.36%
# 14                10.51%    5.36%         17.22%              13.64%
# 15                13.41%    6.49%         22.94%              17.74%
# 16                 9.58%    5.18%         16.82%              12.55%
# 17                10.70%    6.32%         16.70%              16.30%
# 18                13.34%    6.90%         18.46%              13.72%
# 19                14.38%    7.00%         21.88%              16.88%
# 20                13.76%    6.21%         16.04%              15.56%
# 21                10.36%    4.07%         17.64%              11.80%
# 22                12.33%    4.78%         23.54%              16.04%
# 23                13.12%    5.97%         18.38%              16.62%
# 24                12.26%    6.06%         23.03%              17.71%
# 25                13.48%    5.94%         20.38%              15.81%
# 26                 7.96%    6.59%         13.02%              14.54%
# 27                 9.44%    5.80%         16.27%              15.12%
# 28                 6.46%    5.19%         13.55%              11.95%
# 29                 7.41%    4.93%         15.46%              12.13%
# 30                12.52%    6.69%         15.96%              17.45%
# 31                11.36%    5.26%         15.35%              15.15%
#
#    Perceived health, fair or poor  \
# 0                           7.93%
# 1                          11.03%
# 2                           9.99%
# 3                           7.59%
# 4                           8.43%
# 5                          13.13%
# 6                           9.46%
# 7                           9.16%
# 8                           9.07%
# 9                           7.27%
# 10                          9.90%
# 11                         10.32%
# 12                          9.39%
# 13                         10.17%
# 14                          7.85%
# 15                         11.02%
# 16                          7.71%
# 17                          9.00%
# 18                          6.90%
# 19                          7.63%
# 20                          9.75%
# 21                          8.16%
# 22                          7.46%
# 23                         12.26%
# 24                         10.07%
# 25                         11.88%
# 26                          9.22%
# 27                          7.91%
# 28                          9.98%
# 29                          9.81%
# 30                         11.33%
# 31                          9.94%
#
#    Perceived life stress, most days quite a bit or extremely stressful  \
# 0                                              18.97%
# 1                                              22.15%
# 2                                              14.09%
# 3                                              18.52%
# 4                                              17.76%
# 5                                              17.49%
# 6                                              21.53%
# 7                                              17.23%
# 8                                              18.32%
# 9                                              15.21%
# 10                                             22.46%
# 11                                             18.67%
# 12                                             18.60%
# 13                                             16.14%
# 14                                             21.33%
# 15                                             23.30%
# 16                                             19.80%
# 17                                             17.35%
# 18                                             14.67%
# 19                                             18.13%
# 20                                             16.27%
# 21                                             15.57%
# 22                                             22.75%
# 23                                             19.09%
# 24                                             13.38%
# 25                                             14.68%
# 26                                             19.72%
# 27                                             16.14%
# 28                                             17.63%
# 29                                             15.48%
# 30                                             16.53%
# 31                                             18.31%
#
#    Perceived mental health, fair or poor
# 0                                  5.87%
# 1                                  6.63%
# 2                                  5.55%
# 3                                  5.75%
# 4                                  5.45%
# 5                                  8.35%
# 6                                  6.52%
# 7                                  6.62%
# 8                                  5.73%
# 9                                  4.71%
# 10                                 7.07%
# 11                                 6.66%
# 12                                 6.35%
# 13                                 6.03%
# 14                                 4.30%
# 15                                 6.56%
# 16                                 5.30%
# 17                                 5.84%
# 18                                 6.32%
# 19                                 3.63%
# 20                                 5.90%
# 21                                 4.98%
# 22                                 3.47%
# 23                                 6.59%
# 24                                 4.80%
# 25                                 5.70%
# 26                                 5.12%
# 27                                 1.85%
# 28                                 6.39%
# 29                                 4.91%
# 30                                 6.27%
# 31                                 6.16%

# %% [markdown]
# ### Converting percentages to numbers
